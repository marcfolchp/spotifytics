# %%
from functions import update_user_history, get_user_history_df, get_recently_played_tracks

user = 'bondmarcbond'

# %%
update_user_history(user)
# Out:
# ✅ Updated 49 tracks for 8c6mlvfy7g6uh17103dved543

# %%
get_recently_played_tracks(user)
# Out:
# [{'name': 'Recordé',
#   'artist': 'Milo j',
#   'album': 'La Vida Era Más Corta',
#   'album_image': 'https://i.scdn.co/image/ab67616d0000b273f2a68f2953cbcb349d042e5b',
#   'uri': 'spotify:track:0psq5Vtrp20vhX5kGZu2RO',
#   'played_at': '2025-11-01T19:21:21.374Z'},
#  {'name': 'Llora Llora',
#   'artist': 'Milo j',
#   'album': 'La Vida Era Más Corta',
#   'album_image': 'https://i.scdn.co/image/ab67616d0000b273f2a68f2953cbcb349d042e5b',
#   'uri': 'spotify:track:3fgScn3fp098tqIVgVosd5',
#   'played_at': '2025-11-01T19:18:33.475Z'},
#  {'name': 'Radamel',
#   'artist': 'Milo j',
#   'album': 'La Vida Era Más Corta',
#   'album_image': 'https://i.scdn.co/image/ab67616d0000b273f2a68f2953cbcb349d042e5b',
#   'uri': 'spotify:track:2yJFSmMN7pxOUgZS5kImWU',
#   'played_at': '2025-11-01T19:14:05.236Z'},
#  {'name': 'La Vida Era Más Corta',
#   'artist': 'Milo j',
#   'album': 'La Vida Era Más Corta',
#   'album_image': 'https://i.scdn.co/image/ab67616d0000b273f2a68f2953cbcb349d042e5b',
# ...
