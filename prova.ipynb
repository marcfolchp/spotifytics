# %%
from functions import update_user_history, get_user_history_df

user = '8c6mlvfy7g6uh17103dved543'

# %%
# update_user_history('bondmarcbond')

# %%
get_user_history_df("bondmarcbond")
# Out:
#                             album  \
# 0           La Vida Era Más Corta
# 1                    afroLOVA 25'
# 2                    afroLOVA 25'
# 3                    afroLOVA 25'
# 4                    afroLOVA 25'
# 5                    afroLOVA 25'
# 6                    afroLOVA 25'
# 7                    afroLOVA 25'
# 8                    afroLOVA 25'
# 9           La Vida Era Más Corta
# 10          La Vida Era Más Corta
# 11          La Vida Era Más Corta
# 12          La Vida Era Más Corta
# 13          La Vida Era Más Corta
# 14          La Vida Era Más Corta
# 15          La Vida Era Más Corta
# 16          La Vida Era Más Corta
# 17          La Vida Era Más Corta
# 18          La Vida Era Más Corta
# 19          La Vida Era Más Corta
# 20          La Vida Era Más Corta
# 21          La Vida Era Más Corta
# 22          La Vida Era Más Corta
# 23          La Vida Era Más Corta
# 24          La Vida Era Más Corta
# 25          La Vida Era Más Corta
# ...
