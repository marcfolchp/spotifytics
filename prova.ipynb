# %%
from functions import update_user_history, get_user_history_df, get_total_play_time, get_user_top_artists

user = 'bondmarcbond'

# %%
get_user_top_artists(user)
# Out:
# [{'name': 'Rels B',
#   'genres': ['urbano latino', 'trap latino'],
#   'followers': 10003316,
#   'popularity': 81,
#   'image': 'https://i.scdn.co/image/ab6761610000e5ebbf0eba7a7a19be9e0a5b2315',
#   'uri': 'spotify:artist:2IMZYfNi21MGqxopj9fWx8'},
#  {'name': 'Milo j',
#   'genres': ['argentine trap'],
#   'followers': 8890975,
#   'popularity': 82,
#   'image': 'https://i.scdn.co/image/ab6761610000e5eb33c342a253daee2d1c9d5931',
#   'uri': 'spotify:artist:19HM5j0ULGSmEoRcrSe5x3'},
#  {'name': 'Fred again..',
#   'genres': ['stutter house', 'house'],
#   'followers': 2206565,
#   'popularity': 77,
#   'image': 'https://i.scdn.co/image/ab6761610000e5eb381c41adc678e4ce864eb274',
#   'uri': 'spotify:artist:4oLeXFyACqeem2VImYeBFe'},
#  {'name': 'Mora',
#   'genres': ['urbano latino', 'trap latino', 'reggaeton'],
#   'followers': 8117272,
#   'popularity': 81,
#   'image': 'https://i.scdn.co/image/ab6761610000e5ebe6252cc367480d8fe43e711f',
# ...

# %%
get_total_play_time(user)
# Out:
# 311

# %%
update_user_history(user)

# %%
get_user_history_df(user)
# Out:
#                              album  \
# 0            La Vida Era Más Corta
# 1            La Vida Era Más Corta
# 2            La Vida Era Más Corta
# 3            La Vida Era Más Corta
# 4            La Vida Era Más Corta
# ..                             ...
# 160          La Vida Era Más Corta
# 161          La Vida Era Más Corta
# 162                         United
# 163                  Honky Chateau
# 164  The Stranger (Legacy Edition)
#
#                                            album_image       artist  \
# 0    https://i.scdn.co/image/ab67616d0000b273f2a68f...       Milo j
# 1    https://i.scdn.co/image/ab67616d0000b273f2a68f...       Milo j
# 2    https://i.scdn.co/image/ab67616d0000b273f2a68f...       Milo j
# 3    https://i.scdn.co/image/ab67616d0000b273f2a68f...       Milo j
# 4    https://i.scdn.co/image/ab67616d0000b273f2a68f...       Milo j
# ..                                                 ...          ...
# ...
